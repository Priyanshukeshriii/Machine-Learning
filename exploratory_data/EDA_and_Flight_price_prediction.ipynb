# %% [markdown]
# #### DATASET
# #### Dataset contains information about flight booking options from the website Easemytrip for flight travel between India's top 6 metro cities. There are #### 300261 datapoints and 11 features in the cleaned dataset.
# ####
# #### FEATURES
# #### The various features of the cleaned dataset are explained below:
# #### 1) Airline: The name of the airline company is stored in the airline column. It is a categorical feature having 6 different airlines.
# ####
# #### 2) Flight: Flight stores information regarding the plane's flight code. It is a categorical feature.
# ####
# #### 3) Source City: City from which the flight takes off. It is a categorical feature having 6 unique cities.
# ####
# #### 4) Departure Time: This is a derived categorical feature obtained created by grouping time periods into bins. It stores information about the departure #### time and have 6 unique time labels.
# ####
# #### 5) Stops: A categorical feature with 3 distinct values that stores the number of stops between the source and destination cities.
# ####
# #### 6) Arrival Time: This is a derived categorical feature created by grouping time intervals into bins. It has six distinct time labels and keeps inf orm#ation ###about the arrival time.
# ####
# #### 7) Destination City: City where the flight will land. It is a categorical feature having 6 unique cities.
# ####
# #### 8) Class: A categorical feature that contains information on seat class; it has two distinct values: Business and Economy.
# ####
# #### 9) Duration: A continuous feature that displays the overall amount of time it takes to travel between cities in hours.
# ####
# #### 10)Days Left: This is a derived characteristic that is calculated by subtracting the trip date by the booking date.
# ####
# #### 11) Price: Target variable stores information of the ticket price.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('flight_price.xlsx')

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
#basic info about the data
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  str
#  1   Date_of_Journey  10683 non-null  str
#  2   Source           10683 non-null  str
#  3   Destination      10683 non-null  str
#  4   Route            10682 non-null  str
#  5   Dep_Time         10683 non-null  str
#  6   Arrival_Time     10683 non-null  str
#  7   Duration         10683 non-null  str
#  8   Total_Stops      10682 non-null  str
#  9   Additional_Info  10683 non-null  str
#  10  Price            10683 non-null  int64
# dtypes: int64(1), str(10)
# memory usage: 918.2 KB

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
## feacture engineering
df['Date']=df['Date_of_Journey'].str.split('/').str[0]

# %%
df.Date
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4        01
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681    01
# 10682     9
# Name: Date, Length: 10683, dtype: object

# %%
df['Month'] = df['Date_of_Journey'].str.split('/').str[1]
df['Year'] = df['Date_of_Journey'].str.split('/').str[2]

# %%
df[['Date', 'Month', 'Year']]
# Out:
#       Date Month  Year
# 0       24    03  2019
# 1        1    05  2019
# 2        9    06  2019
# 3       12    05  2019
# 4       01    03  2019
# ...    ...   ...   ...
# 10678    9    04  2019
# 10679   27    04  2019
# 10680   27    04  2019
# 10681   01    03  2019
# 10682    9    05  2019
#
# [10683 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  str
#  1   Date_of_Journey  10683 non-null  str
#  2   Source           10683 non-null  str
#  3   Destination      10683 non-null  str
#  4   Route            10682 non-null  str
#  5   Dep_Time         10683 non-null  str
#  6   Arrival_Time     10683 non-null  str
#  7   Duration         10683 non-null  str
#  8   Total_Stops      10682 non-null  str
#  9   Additional_Info  10683 non-null  str
#  10  Price            10683 non-null  int64
#  11  Date             10683 non-null  object
#  12  Month            10683 non-null  object
#  13  Year             10683 non-null  object
# dtypes: int64(1), object(3), str(10)
# memory usage: 1.1+ MB

# %%
df['Date']= df['Date'].astype('Int64')
df['Month']=df['Month'].astype('Int64')
df['Year']=df['Year'].astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  str
#  1   Date_of_Journey  10683 non-null  str
#  2   Source           10683 non-null  str
#  3   Destination      10683 non-null  str
#  4   Route            10682 non-null  str
#  5   Dep_Time         10683 non-null  str
#  6   Arrival_Time     10683 non-null  str
#  7   Duration         10683 non-null  str
#  8   Total_Stops      10682 non-null  str
#  9   Additional_Info  10683 non-null  str
#  10  Price            10683 non-null  int64
#  11  Date             10683 non-null  Int64
#  12  Month            10683 non-null  Int64
#  13  Year             10683 non-null  Int64
# dtypes: Int64(3), int64(1), str(10)
# memory usage: 1.2 MB

# %%
df.drop('Date_of_Journey', axis= 1, inplace= True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3  2019
# 1         13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882     9      6  2019
# 3         23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4         21:35   4h 45m      1 stop         No info  13302     1      3  2019

# %%
df.tail()
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  \
# 10678        22:25   2h 30m    non-stop         No info   4107     9      4
# 10679        23:20   2h 35m    non-stop         No info   4145    27      4
# 10680        11:20       3h    non-stop         No info   7229    27      4
# 10681        14:10   2h 40m    non-stop         No info  12648     1      3
# 10682        19:15   8h 20m     2 stops         No info  11753     9      5
#
#        Year
# 10678  2019
# 10679  2019
# 10680  2019
# 10681  2019
# 10682  2019

# %%
df.Dep_Time.unique()
# Out:
# <StringArray>
# ['22:20', '05:50', '09:25', '18:05', '16:50', '09:00', '18:55', '08:00',
#  '08:55', '11:25',
#  ...
#  '15:35', '13:40', '07:20', '04:50', '12:45', '10:25', '12:05', '11:20',
#  '21:40', '03:00']
# Length: 222, dtype: str

# %%
df['Arrival_Time'] = df['Arrival_Time'].apply(lambda x: x.split(' ')[0])

# %%
df["Arrival_hour"]= df['Arrival_Time'].str.split(':').str[0]
df["Arrival_min"]= df['Arrival_Time'].str.split(':').str[1]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  Year  \
# 0        01:10   2h 50m    non-stop         No info   3897    24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2        04:25      19h     2 stops         No info  13882     9      6  2019
# 3        23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4        21:35   4h 45m      1 stop         No info  13302     1      3  2019
#
#   Arrival_hour Arrival_min
# 0           01          10
# 1           13          15
# 2           04          25
# 3           23          30
# 4           21          35

# %%
df.drop("Arrival_Time", axis=1,inplace=True)

# %%
df['Dep_hour']=df['Dep_Time'].str.split(':').str[0]
df['Dep_min']=df['Dep_Time'].str.split(':').str[1]

# %%
df.tail()
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#       Duration Total_Stops Additional_Info  Price  Date  Month  Year  \
# 10678   2h 30m    non-stop         No info   4107     9      4  2019
# 10679   2h 35m    non-stop         No info   4145    27      4  2019
# 10680       3h    non-stop         No info   7229    27      4  2019
# 10681   2h 40m    non-stop         No info  12648     1      3  2019
# 10682   8h 20m     2 stops         No info  11753     9      5  2019
#
#       Arrival_hour Arrival_min Dep_hour Dep_min
# 10678           22          25       19      55
# 10679           23          20       20      45
# 10680           11          20       08      20
# 10681           14          10       11      30
# 10682           19          15       10      55

# %%
df.drop("Dep_Time", axis=1,inplace=True)

# %%
df["Arrival_hour"] = df["Arrival_hour"].astype("Int64")
df["Arrival_min"] = df["Arrival_min"].astype("Int64")
df["Dep_min"] = df["Dep_min"].astype("Int64")
df["Dep_hour"] = df["Dep_hour"].astype("Int64")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  str
#  1   Source           10683 non-null  str
#  2   Destination      10683 non-null  str
#  3   Route            10682 non-null  str
#  4   Duration         10683 non-null  str
#  5   Total_Stops      10682 non-null  str
#  6   Additional_Info  10683 non-null  str
#  7   Price            10683 non-null  int64
#  8   Date             10683 non-null  Int64
#  9   Month            10683 non-null  Int64
#  10  Year             10683 non-null  Int64
#  11  Arrival_hour     10683 non-null  Int64
#  12  Arrival_min      10683 non-null  Int64
#  13  Dep_hour         10683 non-null  Int64
#  14  Dep_min          10683 non-null  Int64
# dtypes: Int64(7), int64(1), str(7)
# memory usage: 1.3 MB

# %%
df['Total_Stops'].unique()
# Out:
# <StringArray>
# ['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops']
# Length: 6, dtype: str

# %%
df['Total_Stops'].isnull().sum()
# Out:
# np.int64(1)

# %%
df[df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Duration Total_Stops Additional_Info  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m         NaN         No info
#
#       Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min
# 9039   7480     6      5  2019             9           25         9       45

# %%
df['Total_Stops'].mode()
# Out:
# 0    1 stop
# Name: Total_Stops, dtype: str

# %%
df['Total_Stops'].unique()
# Out:
# <StringArray>
# ['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops']
# Length: 6, dtype: str

# %%
df['Total_Stops'] = df['Total_Stops'].map({'non-stop':0, '2 stops':2, '1 stop' : 1, '3 stops':3, np.nan : 1, '4 stops':4})

# %%
df
# Out:
#            Airline    Source Destination                  Route Duration  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR   2h 30m
# 10679    Air India   Kolkata    Banglore              CCU → BLR   2h 35m
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL       3h
# 10681      Vistara  Banglore   New Delhi              BLR → DEL   2h 40m
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK   8h 20m
#
#        Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_hour  \
# 0                0         No info   3897    24      3  2019             1
# 1                2         No info   7662     1      5  2019            13
# 2                2         No info  13882     9      6  2019             4
# 3                1         No info   6218    12      5  2019            23
# 4                1         No info  13302     1      3  2019            21
# ...            ...             ...    ...   ...    ...   ...           ...
# 10678            0         No info   4107     9      4  2019            22
# 10679            0         No info   4145    27      4  2019            23
# 10680            0         No info   7229    27      4  2019            11
# 10681            0         No info  12648     1      3  2019            14
# 10682            2         No info  11753     9      5  2019            19
#
#        Arrival_min  Dep_hour  Dep_min
# 0               10        22       20
# 1               15         5       50
# 2               25         9       25
# 3               30        18        5
# 4               35        16       50
# ...            ...       ...      ...
# 10678           25        19       55
# 10679           20        20       45
# 10680           20         8       20
# 10681           10        11       30
# 10682           15        10       55
#
# [10683 rows x 15 columns]

# %%
df['Destination'].unique()
# Out:
# <StringArray>
# ['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad']
# Length: 6, dtype: str

# %%
df['Duration_hour'] = (
    df['Duration']
    .str.extract(r'(\d+)h')
    .fillna(0)
)

df['Duration_min'] = (
    df['Duration']
    .str.extract(r'(\d+)m')
    .fillna(0)
)

# %%
df['Duration_hour'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', 0, '41', '40'], dtype=object)

# %%
df['Duration_min'].unique()
# Out:
# array(['50', '25', 0, '45', '30', '5', '15', '35', '10', '20', '55', '40'],
#       dtype=object)

# %%
df['Duration_hour']=df['Duration_hour'].astype('Int64')
df['Duration_min']=df['Duration_min'].astype('Int64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\arrays\integer.py:63, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      62 try:
# ---> 63     return values.astype(dtype, casting="safe", copy=copy)
#      64 except TypeError as err:
#
# TypeError: Cannot cast array data from dtype('O') to dtype('int64') according to the rule 'safe'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df['Duration_hour']=df['Duration_hour'].astype('Int64')
#       2 df['Duration_min']=df['Duration_min'].astype('Int64')
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\internals\blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\dtypes\astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\dtypes\astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\dtypes\astype.py:81, in _astype_nansafe(arr, dtype, copy, skipna)
#      79 # dispatch on extension dtype if needed
#      80 if isinstance(dtype, ExtensionDtype):
# ---> 81     return dtype.construct_array_type()._from_sequence(arr, dtype=dtype, copy=copy)
#      83 elif not isinstance(dtype, np.dtype):  # pragma: no cover
#      84     raise ValueError("dtype must be np.dtype or ExtensionDtype")
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\arrays\masked.py:161, in BaseMaskedArray._from_sequence(cls, scalars, dtype, copy)
#     159 @classmethod
#     160 def _from_sequence(cls, scalars, *, dtype=None, copy: bool = False) -> Self:
# --> 161     values, mask = cls._coerce_to_array(scalars, dtype=dtype, copy=copy)
#     162     return cls(values, mask)
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\arrays\numeric.py:293, in NumericArray._coerce_to_array(cls, value, dtype, copy)
#     288 @classmethod
#     289 def _coerce_to_array(
#     290     cls, value, *, dtype: DtypeObj, copy: bool = False
#     291 ) -> tuple[np.ndarray, np.ndarray]:
#     292     dtype_cls = cls._dtype_cls
# --> 293     values, mask = _coerce_to_data_and_mask(value, dtype, copy, dtype_cls)
#     294     return values, mask
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\arrays\numeric.py:248, in _coerce_to_data_and_mask(values, dtype, copy, dtype_cls)
#     246     values = values.astype(dtype, copy=copy)
#     247 else:
# --> 248     values = dtype_cls._safe_cast(values, dtype, copy=False)
#     249 return values, mask
#
# File d:\udemy\ML\venv1\Lib\site-packages\pandas\core\arrays\integer.py:69, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      66 if (casted == values).all():
#      67     return casted
# ---> 69 raise TypeError(
#      70     f"cannot safely cast non-equivalent {values.dtype} to {np.dtype(dtype)}"
#      71 ) from err
#
# TypeError: cannot safely cast non-equivalent object to int64

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#    Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_hour  \
# 0            0         No info   3897    24      3  2019             1
# 1            2         No info   7662     1      5  2019            13
#
#    Arrival_min  Dep_hour  Dep_min Duration_hour Duration_min
# 0           10        22       20             2           50
# 1           15         5       50             7           25

# %%
df["Airline"].unique()
# Out:
# <StringArray>
# [                           'IndiGo',                         'Air India',
#                        'Jet Airways',                          'SpiceJet',
#                  'Multiple carriers',                             'GoAir',
#                            'Vistara',                          'Air Asia',
#            'Vistara Premium economy',              'Jet Airways Business',
#  'Multiple carriers Premium economy',                            'Trujet']
# Length: 12, dtype: str

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()

# %%
encoded = encoder.fit_transform(df[["Airline", "Source" , 'Destination']]).toarray()

# %%
encoded_df = pd.DataFrame(encoded, columns=encoder.get_feature_names_out())

# %%
df = pd.concat([df, encoded_df],axis=1)

# %%
df.head(1)
# Out:
#   Airline    Source Destination      Route Duration  Total_Stops  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL   2h 50m            0
#
#   Additional_Info  Price  Date  Month  ...  Source_Chennai  Source_Delhi  \
# 0         No info   3897    24      3  ...             0.0           0.0
#
#    Source_Kolkata  Source_Mumbai  Destination_Banglore Destination_Cochin  \
# 0             0.0            0.0                   0.0                0.0
#
#   Destination_Delhi  Destination_Hyderabad  Destination_Kolkata  \
# 0               0.0                    0.0                  0.0
#
#    Destination_New Delhi
# 0                    1.0
#
# [1 rows x 40 columns]

# %%
df.drop(['Airline','Destination','Source', 'Route','Duration'], axis=1, inplace=True)

# %%
df.head(1)
# Out:
#    Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_hour  \
# 0            0         No info   3897    24      3  2019             1
#
#    Arrival_min  Dep_hour  Dep_min  ... Source_Chennai Source_Delhi  \
# 0           10        22       20  ...            0.0          0.0
#
#    Source_Kolkata  Source_Mumbai  Destination_Banglore  Destination_Cochin  \
# 0             0.0            0.0                   0.0                 0.0
#
#    Destination_Delhi  Destination_Hyderabad  Destination_Kolkata  \
# 0                0.0                    0.0                  0.0
#
#    Destination_New Delhi
# 0                    1.0
#
# [1 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Total_Stops                                10683 non-null  int64
#  1   Additional_Info                            10683 non-null  str
#  2   Price                                      10683 non-null  int64
#  3   Date                                       10683 non-null  Int64
#  4   Month                                      10683 non-null  Int64
#  5   Year                                       10683 non-null  Int64
#  6   Arrival_hour                               10683 non-null  Int64
#  7   Arrival_min                                10683 non-null  Int64
#  8   Dep_hour                                   10683 non-null  Int64
#  9   Dep_min                                    10683 non-null  Int64
#  10  Duration_hour                              10683 non-null  object
#  11  Duration_min                               10683 non-null  object
#  12  Airline_Air Asia                           10683 non-null  float64
#  13  Airline_Air India                          10683 non-null  float64
#  14  Airline_GoAir                              10683 non-null  float64
#  15  Airline_IndiGo                             10683 non-null  float64
#  16  Airline_Jet Airways                        10683 non-null  float64
#  17  Airline_Jet Airways Business               10683 non-null  float64
#  18  Airline_Multiple carriers                  10683 non-null  float64
#  19  Airline_Multiple carriers Premium economy  10683 non-null  float64
#  20  Airline_SpiceJet                           10683 non-null  float64
#  21  Airline_Trujet                             10683 non-null  float64
#  22  Airline_Vistara                            10683 non-null  float64
#  23  Airline_Vistara Premium economy            10683 non-null  float64
#  24  Source_Banglore                            10683 non-null  float64
#  25  Source_Chennai                             10683 non-null  float64
#  26  Source_Delhi                               10683 non-null  float64
#  27  Source_Kolkata                             10683 non-null  float64
#  28  Source_Mumbai                              10683 non-null  float64
#  29  Destination_Banglore                       10683 non-null  float64
#  30  Destination_Cochin                         10683 non-null  float64
#  31  Destination_Delhi                          10683 non-null  float64
#  32  Destination_Hyderabad                      10683 non-null  float64
#  33  Destination_Kolkata                        10683 non-null  float64
#  34  Destination_New Delhi                      10683 non-null  float64
# dtypes: Int64(7), float64(23), int64(2), object(2), str(1)
# memory usage: 2.9+ MB

# %%
df.describe()
# Out:
#         Total_Stops         Price       Date     Month     Year  Arrival_hour  \
# count  10683.000000  10683.000000    10683.0   10683.0  10683.0       10683.0
# mean       0.824207   9087.064121  13.508378  4.708602   2019.0     13.348778
# std        0.675199   4611.359167   8.479277  1.164357      0.0      6.859125
# min        0.000000   1759.000000        1.0       3.0   2019.0           0.0
# 25%        0.000000   5277.000000        6.0       3.0   2019.0           8.0
# 50%        1.000000   8372.000000       12.0       5.0   2019.0          14.0
# 75%        1.000000  12373.000000       21.0       6.0   2019.0          19.0
# max        4.000000  79512.000000       27.0       6.0   2019.0          23.0
#
#        Arrival_min   Dep_hour    Dep_min  Airline_Air Asia  ...  \
# count      10683.0    10683.0    10683.0      10683.000000  ...
# mean      24.69063  12.490686  24.411214          0.029861  ...
# std      16.506036    5.74865   18.76798          0.170210  ...
# min            0.0        0.0        0.0          0.000000  ...
# 25%           10.0        8.0        5.0          0.000000  ...
# 50%           25.0       11.0       25.0          0.000000  ...
# 75%           35.0       18.0       40.0          0.000000  ...
# max           55.0       23.0       55.0          1.000000  ...
#
#        Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai  \
# count    10683.000000  10683.000000    10683.000000   10683.000000
# mean         0.035664      0.424693        0.268745       0.065244
# std          0.185460      0.494320        0.443328       0.246967
# min          0.000000      0.000000        0.000000       0.000000
# 25%          0.000000      0.000000        0.000000       0.000000
# 50%          0.000000      0.000000        0.000000       0.000000
# 75%          0.000000      1.000000        1.000000       0.000000
# max          1.000000      1.000000        1.000000       1.000000
#
#        Destination_Banglore  Destination_Cochin  Destination_Delhi  \
# count          10683.000000        10683.000000       10683.000000
# mean               0.268745            0.424693           0.118412
# std                0.443328            0.494320           0.323111
# min                0.000000            0.000000           0.000000
# 25%                0.000000            0.000000           0.000000
# 50%                0.000000            0.000000           0.000000
# 75%                1.000000            1.000000           0.000000
# max                1.000000            1.000000           1.000000
#
#        Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# count           10683.000000         10683.000000           10683.000000
# mean                0.065244             0.035664               0.087241
# std                 0.246967             0.185460               0.282202
# min                 0.000000             0.000000               0.000000
# 25%                 0.000000             0.000000               0.000000
# 50%                 0.000000             0.000000               0.000000
# 75%                 0.000000             0.000000               0.000000
# max                 1.000000             1.000000               1.000000
#
# [8 rows x 32 columns]
