# %% [markdown]
# Abstraction In OOPS

# %%
from abc import ABC, abstractmethod

# %%
# abstract base class
class Vehicle(ABC):
    def drive(self):
        print("Driving a vehicle")
    
    @abstractmethod
    def fuel_type(self):
        pass

# concrete class
class Car(Vehicle):
    def fuel_type(self):
        return "Petrol"
